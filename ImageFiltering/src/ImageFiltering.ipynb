# %% [markdown]
# ## Import package

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image, ImageFilter
plt.rcParams["figure.figsize"] = (20, 20)

# %% [markdown]
# ## Lọc trung bình (Arithmetic Mean Filtered)

# %%
img = cv2.imread("../data/salt_noise.jpg")

# %%
filtered_img = cv2.blur(gaussian_noise, (5, 5))

# %%
plt.subplot(121),plt.imshow(cv2.cvtColor(gaussian_noise, cv2.COLOR_BGR2RGB)),plt.title('Gaussian Noise')
plt.subplot(122),plt.imshow(cv2.cvtColor(filtered_img, cv2.COLOR_BGR2RGB)),plt.title('Arithmetic Mean Filtered')
plt.show()

# %% [markdown]
# ## Gaussian

# %%
gaussian_noise = cv2.imread("../data/Gaussian-Noise.jpg")
gaussian_img = cv2.GaussianBlur(gaussian_noise,(5,5),0)

# %%
plt.subplot(121),plt.imshow(cv2.cvtColor(gaussian_noise, cv2.COLOR_BGR2RGB)),plt.title('Gaussian Noise')
plt.subplot(122),plt.imshow(cv2.cvtColor(gaussian_img, cv2.COLOR_BGR2RGB)),plt.title('Gaussian Filtered')
plt.show()

# %% [markdown]
# ## Lọc trung vị (Median Filter)

# %%
median_img = cv2.medianBlur(img, 5)
plt.subplot(121),plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB)),plt.title('Salt and Pepper Noise')
plt.subplot(122),plt.imshow(cv2.cvtColor(median_img, cv2.COLOR_BGR2RGB)),plt.title('Median Filtered')
plt.show()
